# %%
import os
import numpy as np

# %%
# List of file IDs in the current directory
file_num = ['01A', '01B','02A', '02B','03A', '03B','04A', '04B','05A', '05B','06A', '06B','07A', '07B','08A', '08B','09A', '09B']

for n in file_num:
    # Downsample the file at 'input_path'
    input_path = '/panfs/dong/3D_registration/Yang_MORF_DragonFly/TME07-1_30x/Camk2a-MORF3-D1Tom_TME07-1_30x_Str_' + n + '.ims'

    image_type = 'ims' # can be ims or Tif

    outdir = '/nafs/dtward/dong/donglab_resample_lightsheet_good_2022_09_06_tmp'

    # !python downsample.py $input_path $image_type $outdir

    # Move the downsampled image from 'src_path_xxx' to 'dest_path'
    src_path_jpg = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_0_pow_[0.125]_down.jpg'
    src_path_npz = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_0_pow_[0.125]_down.npz'

    dest_path = '/nafs/dtward/dong/final_output'

    # !mv $src_path_jpg $dest_path
    print(f"========== Moved jpg {n} ==========")

    # !mv $src_path_npz $dest_path
    print(f"========== Moved npz {n} ==========")
# Out:
# downsample.py:19: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Input path is /panfs/dong/3D_registration/Yang_MORF_DragonFly/TME07-1_30x/Camk2a-MORF3-D1Tom_TME07-1_30x_Str_01A.ims
# Output filename is Camk2a-MORF3-D1Tom_TME07-1_30x_Str_01A_ch_0_pow_[0.125]_down.npz
# Resolution is [0.99786325 0.20095696 0.20098142]
# Desired resolution is 50.0
# Dataset string is DataSet/ResolutionLevel 0/TimePoint 0/Channel 0/Data
# Temp output dir is /nafs/dtward/dong/donglab_resample_lightsheet_good_2022_09_06_tmp
# Finished loading slice 0 of 472, time 0.17185497283935547 s
# Finished loading slice 1 of 472, time 0.10906028747558594 s
# Finished loading slice 2 of 472, time 0.10875630378723145 s
# Finished loading slice 3 of 472, time 0.10884332656860352 s
# Finished loading slice 4 of 472, time 0.11855053901672363 s
# Finished loading slice 5 of 472, time 0.10925865173339844 s
# ...

# %%
src_path_jpg = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_0_pow_[0.125]_down.jpg'
src_path_npz = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_0_pow_[0.125]_down.npz'

dest_path = '/nafs/dtward/dong/final_output'

# !mv $src_path_jpg $dest_path
print("Moved jpg")

# !mv $src_path_npz $dest_path
print("Moved npz")
# Out:
# Moved jpg
# Moved npz

# %%
'/panfs/dong/3D_registration/Yang_MORF_DragonFly/TME07-1_10x/Camk2a-MORF3-D1Tom_TME07-1_10x_0'+str(1)+'.ims'
# Out:
# '/panfs/dong/3D_registration/Yang_MORF_DragonFly/TME07-1_10x/Camk2a-MORF3-D1Tom_TME07-1_10x_01.ims'

# %%
import os

src_path_jpg = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_0_pow_[0.125]_down.jpg'

src_path_jpg
# Out:
# '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/Camk2a-MORF3-D1Tom_TME07-1_10x_01_ch_0_pow_[0.125]_down.jpg'

# %%
import os
import numpy as np

# List of file IDs in the current directory

# subdir = '/panfs/dong/3D_stitched_DF/SW220510-01/SW220510-01_C' # + str(n) + '_DF-10x-2000z_Stitched.ims'
# file_num = ['03','04','07','08','09','10','11','12','13','14','17','18','19','20']

# subdir = '/panfs/dong/3D_registration/Yang_MORF_DragonFly/TME07-1_10x/Camk2a-MORF3-D1Tom_TME07-1_10x_0' # + str(n) + '.ims'
# file_num = np.arange(1,10)

# subdir = '/panfs/dong/3D_registration/Yang_MORF_DragonFly/TME07-1_30x/Camk2a-MORF3-D1Tom_TME07-1_30x_Str_' # + str(n) + '.ims'
# file_num = ['01A', '01B','02A', '02B','03A', '03B','04A', '04B','05A', '05B','06A', '06B','07A', '07B','08A', '08B', '09B']

# subdir = '/panfs/dong/3D_registration/Yang_MORF_DragonFly/TME08-1_10x/Camk2a-MORF3-D1Tom_TME08-1_10x_0' # + str(n) + '.ims'
# file_num = np.arange(1,10)
# final_out = 'TME08'

subdir = '/panfs/dong/3D_registration/Yang_MORF_DragonFly/TME08-1_30x/Camk2a-MORF3-D1Tom_TME08-1_30x_Str_' # + str(n) + '.ims'
file_num = ['01A', '01B','02A', '02B','03A', '03B','04A', '04B','05A', '05B','06A', '06B','07A', '07B','08A', '08B']
final_out = 'TME08'

for n in file_num:
    for c in [0,1]:
        # Downsample the file at 'input_path'
        input_path = subdir + str(n) + '.ims'

        image_type = 'ims' # can be ims or Tif

        outdir = '/nafs/dtward/dong/donglab_resample_lightsheet_good_2022_09_06_tmp'

        # !python downsample.py $input_path $image_type $outdir --channel $c

        # Move the downsampled image from 'src_path_xxx' to 'dest_path'
        src_path_jpg = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_'+str(c)+'_pow_[0.125]_down.jpg'
        src_path_npz = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_'+str(c)+'_pow_[0.125]_down.npz'

        dest_path = '/nafs/dtward/dong/final_output/'+final_out

        # !mv $src_path_jpg $dest_path
        print(f"========== Moved jpg {n}_ch_{c} ==========")

        # !mv $src_path_npz $dest_path
        print(f"========== Moved npz {n}_ch_{c} ==========")

print()
print(f'Finished processing {subdir}')
# Out:
# downsample.py:19: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Input path is /panfs/dong/3D_registration/Yang_MORF_DragonFly/TME08-1_30x/Camk2a-MORF3-D1Tom_TME08-1_30x_Str_01A.ims
# Output filename is Camk2a-MORF3-D1Tom_TME08-1_30x_Str_01A_ch_0_pow_[0.125]_down.npz
# Resolution is [0.99795082 0.20098591 0.20098594]
# Desired resolution is 50.0
# Dataset string is DataSet/ResolutionLevel 0/TimePoint 0/Channel 0/Data
# Temp output dir is /nafs/dtward/dong/donglab_resample_lightsheet_good_2022_09_06_tmp
# Finished loading slice 0 of 488, time 0.1936655044555664 s
# Finished loading slice 1 of 488, time 0.10969829559326172 s
# Finished loading slice 2 of 488, time 0.10919642448425293 s
# Finished loading slice 3 of 488, time 0.10942721366882324 s
# Finished loading slice 4 of 488, time 0.10939908027648926 s
# Finished loading slice 5 of 488, time 0.10924863815307617 s
# ...

# %%
src_path_jpg = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_0_pow_[0.125]_down.jpg'
src_path_npz = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_0_pow_[0.125]_down.npz'

dest_path = '/nafs/dtward/dong/final_output'

# !mv $src_path_jpg $dest_path
print("Moved jpg")

# !mv $src_path_npz $dest_path
print("Moved npz")
# Out:
# Moved jpg
# Moved npz

# %%
# Downsample the file at 'input_path'
#input_path = '/panfs/dong/3D_stitched_DF/SW220510-01/SW220510-01_C07_DF-10x-1000z_Stitched-1.ims'
input_path = '/panfs/dong/3D_stitched_DF/SW220510-01/SW220510-01_C15_DF-10x-1000z_Stitched.ims'


image_type = 'ims' # can be ims or Tif

outdir = '/nafs/dtward/dong/donglab_resample_lightsheet_good_2022_09_06_tmp'

# !python downsample.py $input_path $image_type $outdir -c 1

# Move the downsampled image from 'src_path_xxx' to 'dest_path'
src_path_jpg = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_1_pow_[0.125]_down.jpg'
src_path_npz = '/ifshome/abenneck/image_registration/donglab_workflows/pipeline_building/'+os.path.splitext(os.path.split(input_path)[-1])[0]+'_ch_1_pow_[0.125]_down.npz'

dest_path = '/nafs/dtward/dong/final_output'

# !mv $src_path_jpg $dest_path
print(f"========== Moved jpg ==========")

# !mv $src_path_npz $dest_path
print(f"========== Moved npz ==========")
# Out:
# downsample.py:19: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Input path is /panfs/dong/3D_stitched_DF/SW220510-01/SW220510-01_C15_DF-10x-1000z_Stitched.ims
# Output filename is SW220510-01_C15_DF-10x-1000z_Stitched_ch_1_pow_[0.125]_down.npz
# Resolution is [0.99840213 0.6029667  0.60293216]
# Desired resolution is 50.0
# Dataset string is DataSet/ResolutionLevel 0/TimePoint 0/Channel 1/Data
# Temp output dir is /nafs/dtward/dong/donglab_resample_lightsheet_good_2022_09_06_tmp
# Finished loading slice 0 of 752, time 0.2082686424255371 s
# Finished loading slice 1 of 752, time 0.10907554626464844 s
# Finished loading slice 2 of 752, time 0.11124444007873535 s
# Finished loading slice 3 of 752, time 0.1104583740234375 s
# Finished loading slice 4 of 752, time 0.11000609397888184 s
# Finished loading slice 5 of 752, time 0.1204824447631836 s
# ...

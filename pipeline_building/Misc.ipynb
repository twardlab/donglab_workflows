# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
I = plt.imread(r'/nafs/dtward/dong/final_output/SW220510_LS/SW220510_02_LS_6x_1000z_ch_0_pow_[0.125]_down.jpg')
plt.imshow(I)

# %%
I = plt.imread(r'/nafs/dtward/dong/final_output/SW220510_LS/SW220510_02_LS_6x_1000z_ch_1_pow_[0.125]_down.jpg')
plt.imshow(I)
